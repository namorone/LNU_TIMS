# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib widget



def read_from_file(path):
    with open(path) as f:
        lines = [i.replace("\n", "") for i in f.readlines()]
        matrix = [[float(j) for j in i.split(",")] for i in lines]
    return matrix

matrix = read_from_file("Data.txt")

def get_x_i(matrix):
    return matrix[0][1:]

def get_y_i(matrix):
    return [matrix[i][0] for i in range(1, len(matrix))]

arr_x = get_x_i(matrix)

arr_y = get_y_i(matrix)





def get_n_i(matrix):
    return [sum([matrix[i][j] for i in range(1, len(matrix))]) for j in range(1, len(matrix[0]))]
def get_m_i(matrix):
    return [sum(matrix[i][1:]) for i in range(1, len(matrix))]

y_vybirkovi = []


def Y_vybirkove():
    yi = []
    for i in range(len(arr_y)+1):
        elems = []
        for j in range(len(arr_x) - 1):
            elem = matrix[j + 1][i + 1] * arr_y[j]
            elems.append(elem)
        yi.append(sum(elems))

    result = [y / get_n_i(matrix)[i] for i, y in enumerate(yi)]
    return result




y_vybirkovi = Y_vybirkove()




new_y = [round(i, 3) for i in y_vybirkovi]

print(new_y)

x_values, y_values = arr_x, y_vybirkovi
df = pd.DataFrame({'X': x_values, '-Y': new_y})
print(df)
# Побудова графіка
x = np.linspace(0, 5, 100)


# Обчислення значень показникової функції для кожного x
y = np.sqrt(x_values)

plt.plot(x_values, y_values , marker='o', linestyle='-', color='blue')
#plt.plot(x,100*x**2, color='red')
plt.plot(x_values,y, marker='o',color = 'green')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Графік точок(x,y-)')
plt.grid(True)
plt.show()


#1)
#3) exponent corelation yx = ba^x,  a,b -?
# Out:
# [1.042, 1.516, 2.037, 2.457, 3.409, 3.8, 4.0]
#       X     -Y
# 0   3.0  1.042
# 1   6.0  1.516
# 2   7.0  2.037
# 3  10.0  2.457
# 4  13.0  3.409
# 5  15.0  3.800
# 6  17.0  4.000
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pip install ipympl
# Out:
# Collecting ipympl
#   Downloading ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
#      -------------------------------------- 511.6/511.6 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: ipython<9 in c:\users\roman\anaconda3\lib\site-packages (from ipympl) (8.10.0)
# Requirement already satisfied: numpy in c:\users\roman\anaconda3\lib\site-packages (from ipympl) (1.23.5)
# Requirement already satisfied: ipython-genutils in c:\users\roman\anaconda3\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: traitlets<6 in c:\users\roman\anaconda3\lib\site-packages (from ipympl) (5.7.1)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\users\roman\anaconda3\lib\site-packages (from ipympl) (3.7.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\roman\anaconda3\lib\site-packages (from ipympl) (7.6.5)
# Requirement already satisfied: pillow in c:\users\roman\anaconda3\lib\site-packages (from ipympl) (9.4.0)
# Requirement already satisfied: pickleshare in c:\users\roman\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: decorator in c:\users\roman\anaconda3\lib\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\roman\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\roman\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\roman\anaconda3\lib\site-packages (from ipython<9->ipympl) (2.11.2)
# Requirement already satisfied: matplotlib-inline in c:\users\roman\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\roman\anaconda3\lib\site-packages (from ipython<9->ipympl) (3.0.36)
# Requirement already satisfied: colorama in c:\users\roman\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.4.6)
# Requirement already satisfied: backcall in c:\users\roman\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\roman\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.7.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\roman\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\roman\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\roman\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\roman\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\roman\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\roman\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\roman\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\roman\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\roman\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\roman\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (22.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\roman\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\roman\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in c:\users\roman\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\roman\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.1)
# Requirement already satisfied: psutil in c:\users\roman\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.0)
# Requirement already satisfied: nest-asyncio in c:\users\roman\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\roman\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\roman\anaconda3\lib\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: jupyter-core in c:\users\roman\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (5.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\roman\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\roman\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.17.3)
# Requirement already satisfied: wcwidth in c:\users\roman\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\roman\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\roman\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.5.2)
# Requirement already satisfied: pure-eval in c:\users\roman\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\roman\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (2.0.5)
# Requirement already satisfied: executing in c:\users\roman\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\roman\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\roman\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (22.1.0)
# Requirement already satisfied: entrypoints in c:\users\roman\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\roman\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\roman\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (305.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\roman\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\roman\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.2)
# Requirement already satisfied: jinja2 in c:\users\roman\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (3.1.2)
# Requirement already satisfied: argon2-cffi in c:\users\roman\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\roman\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\roman\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.5.4)
# Requirement already satisfied: prometheus-client in c:\users\roman\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.14.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\roman\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\roman\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.23.4)
# Requirement already satisfied: bleach in c:\users\roman\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\roman\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\roman\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.1.1)
# Requirement already satisfied: defusedxml in c:\users\roman\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: lxml in c:\users\roman\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.9.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\roman\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\roman\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.13)
# Requirement already satisfied: tinycss2 in c:\users\roman\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\roman\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\roman\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\roman\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\roman\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: websocket-client in c:\users\roman\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.58.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\roman\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (3.5.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\roman\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\roman\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\roman\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: idna>=2.8 in c:\users\roman\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\roman\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\roman\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.21)
# Installing collected packages: ipympl
# Successfully installed ipympl-0.9.3
# Note: you may need to restart the kernel to use updated packages.
